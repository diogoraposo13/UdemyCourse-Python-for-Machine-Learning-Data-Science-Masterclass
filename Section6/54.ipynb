# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,11,10)

# %%
x
# Out:
# array([ 0.        ,  1.22222222,  2.44444444,  3.66666667,  4.88888889,
#         6.11111111,  7.33333333,  8.55555556,  9.77777778, 11.        ])

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

#ax.plot(x,x, color='#1a2781', lw=10, ls=':')

#ax.plot(x,x+1,color='red', linewidth=1, marker='o',ls='--', ms=10)

ax.plot(x,x,color='purple', linewidth=1, marker='+',ls='--', markersize=20, markerfacecolor='orange',markeredgewidth=4,markeredgecolor='green')

# %%
type(lines)
# Out:
# list
